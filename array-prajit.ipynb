# %%
# minimum cost of the traversal 
def minimum_removal_cost(A):
    n=len(A)
    if n<=1:
        return 0
    previous_left=[0]*n
    previous_right=[0]*n

    for length in range[2,n+1]:
        current_left=[0]*n
        current_right=[0]*n

    for left in range(n-length +1):
        right=left+length -1

        option1=( previous_left[left+1]+abs(A[left]-A[left + 1]))
        option2=(previous_right[left+1]+abs(A[left]-A[right]))


# def minimum_removal_cost(A):
#     n = len(A)

#     if n <= 1:
#         return 0

#     # For intervals of length 1, cost is zero.
#     previous_left = [0] * n
#     previous_right = [0] * n

#     # Build intervals of length 2, 3, ..., n.
#     for length in range(2, n + 1):
#         current_left = [0] * n
#         current_right = [0] * n

#         for left in range(n - length + 1):
#             right = left + length - 1

#             # Add A[left] as the latest element.
#             option1 = (
#                 previous_left[left + 1]
#                 + abs(A[left] - A[left + 1])
#             )

#             option2 = (
#                 previous_right[left + 1]
#                 + abs(A[left] - A[right])
#             )

#             current_left[left] = min(option1, option2)

#             # Add A[right] as the latest element.
#             option3 = (
#                 previous_left[left]
#                 + abs(A[right] - A[left])
#             )

#             option4 = (
#                 previous_right[left]
#                 + abs(A[right] - A[right - 1])
#             )

#             current_right[left] = min(option3, option4)

#         previous_left = current_left
#         previous_right = current_right

#     return min(previous_left[0], previous_right[0])


# n = int(input())
# A = list(map(int, input().split()))

# print(minimum_removal_cost(A))
