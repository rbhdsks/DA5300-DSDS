# %% [markdown]
# ## My list Tuple examples

# %% [markdown]
# List: here list can be anything, unlike c++ where arr is just a set of a datatype. This has a dynamic memory and need not be a uniform datatype. Size of list os also felxible.

# %%
l=[1,2,3,4,5, 'y',"kgfgu"]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'y', 'kgfgu']

# %% [markdown]
# and it is a sequence like strings ha...

# %%
l[6]
# Out:
# 'kgfgu'

# %% [markdown]
# and it also has a extra layer of indexing as well

# %%
l[6][0]
# Out:
# 'k'
