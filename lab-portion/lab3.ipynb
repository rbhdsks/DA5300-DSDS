# %% [markdown]
# ### Lab 3 wise, saara code

# %% [markdown]
# There are 3 things:
# - Singly linked list
# - Doubly linked list
# - Positional list ADT

# %%
# class SinglyNode:
#     def __init__(self, element):
#         self.element=element
#         self.next=None
# class Singlylist:
#     def __init__(self):
#         self.head=None
#     def is_empty(self):
#         return self.head is None
#     def add_first(self,element):
#         new_node=SinglyNode(element)
#     def add_last(self,element):
#         new_node=Singlynode(element)


# failed one have to study a bit more and well

# %% [markdown]
# Singly linked list(node +append+ display)

# %%
class Node:
    def __init__(self,element,next=None):
        self.element=element
        self.next=next
class SinglyLinkedlist:
    def __init__(self):
        self.head=None
    def is_empty(self):
        return self.head is None
    def add_first(self,x):
        new=Node(x)
        if self.head is None:
            self.head=new
            return
        cur=self.head
        while cur.next:
            cur=cur.next
        cur.next=new
    def display(self):
        cur=self.head
        while cur:
            print(cur.element, end=' ')
            cur=cur.next
        print()

# %%
def reverse_linked_list(head):
    prev=None
    cur=head
    while cur:
        nxt=cur.next
        cur.next=prev
        prev=cur
        cur = nxt
    return prev

# %%
class Node:
    def _init_(self,element,next=None):
        self.element=element
        self.next=next
        
class SinglyLinkedList:
    def _init_(self):
        self.head=None

    def is_empty(self):
        return self.head is None

    def add_first(self,x):
        if self.is_empty():
            self.head=x
        self.head=Node(x,self.head)

    def add_last(self,x):
        new=Node(x)
        if self.is_empty():
            self.head=Node(x)
            return
        cur=self.head
        while cur.next:
            cur=cur.next
        cur.next=new

    def display(self):
        cur=self.head
        while cur.next:
            print(cur.element)
            cur=cur.next
        print("None")

    def remove_first_occurence(self,x):
        if self.is_empty():
            return

        if self.head.element==x:
            self.head=self.head.next
            return
        
        new=Node(x)
        cur=self.head
        while cur.next:
            if cur.element==new.element:
                cur=cur.next.next
                return
            cur=cur.next
            
    def all_occurences(self,x):

        while self.head and self.head.element==x:
            self.head=self.head.next
            
        cur=self.head
        new=x
        while cur and cur.next:
            if cur.next.element==x:
                cur.next=cur.next.next
            else:
                cur=cur.next

# %%
class Node:
    def __init__(self,element, next=None):
        self.element=element
        self.next
class Singlylinkedlist:
    def __init__(self):
        self.head=None
    def is_empty(self):
        return self.head is None
    def add_first(self, x):
        if self.is_empty():
            self.head=x
        self.head=x
        self.head=Node(x,self.head)
    def add_last(self,x):
        new=Node(x)
        if self.is_empty():
            self.head=Node
