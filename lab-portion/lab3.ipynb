# %% [markdown]
# ### Lab 3 wise, saara code

# %% [markdown]
# There are 3 things:
# - Singly linked list
# - Doubly linked list
# - Positional list ADT

# %%
# class SinglyNode:
#     def __init__(self, element):
#         self.element=element
#         self.next=None
# class Singlylist:
#     def __init__(self):
#         self.head=None
#     def is_empty(self):
#         return self.head is None
#     def add_first(self,element):
#         new_node=SinglyNode(element)
#     def add_last(self,element):
#         new_node=Singlynode(element)


# failed one have to study a bit more and well

# %% [markdown]
# how to create a node in linkedlist
# -
