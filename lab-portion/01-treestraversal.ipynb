# %%
# simple pre-order traversal code
class Node:
    def __init__(self, key):
        self.key=key
        self.left=None
        self.right=None
def preorder(node,result):
    if node is None:
        return
    result.append(node.key)
    preorder(node.left, result)
    preorder(node.right, result)
root=Node("A")
root.left=Node("B")
root.right=Node("C")
root.left.left=Node("D")
root.left.right=Node("E")
root.right.left=Node("F")
root.right.right=Node("G")
result=[]
preorder(root,result)
print(result)
print(" ".join(result))
# Out:
# ['A', 'B', 'D', 'E', 'C', 'F', 'G']
# A B D E C F G

# %%
class Node:
    def __init__(self,key):
        self.key=key
        self.left=None
        self.right=None
def preorder(node,result):
    if node is None:
        return
    result.append(node.key)
    preorder(node.left,result)
    preorder(node.right,result)
root=Node(10)
root.left=Node(20)
root.right=Node(30)
root.left.left=Node(40)
root.left.right=Node(50)
root.right.left=Node(60)
root.right.right=Node(70)
result=[]
preorder(root,result)
print(result)
print(" ".join(map(str, result)))
# Out:
# [10, 20, 40, 50, 30, 60, 70]
# 10 20 40 50 30 60 70

# %% [markdown]
#  Now inorder traversal ka

# %%
class Node:
    def __init__(self,key):
        self.key=key
        self.left=None
        self.right=None
root=Node(8)
root.left=Node(4)
root.right=Node(12)
root.left.right=Node(6)
root.right.left=Node(10)
root.right.right=Node(14)
root.left.right.left=Node(5)

def inorder(node,result):
    if node is None:
        return
    inorder(node.left, result)
    result.append(node.key)
    inorder(node.right, result)


result=[]
inorder(root,result)
print(result)
# Out:
# [4, 5, 6, 8, 10, 12, 14]

# %%
class Node:
    def __init__(self,key):
        self.key=key
        self.left=None
        self.right=None
root=Node(10)
root.left=Node(30)
root.right=Node(20)
root.left.left=Node(5)
root.left.right=Node(40)
root.right.right=Node(15)
root.left.right.left=Node(35)
def inorder(node,result):
    if node is None:
        return
    inorder(node.left, result)
    result.append(node.key)
    inorder(node.right,result)
result=[]
inorder(root,result)
print(result)
# Out:
# [5, 30, 35, 40, 10, 20, 15]

# %%
class Node:
    def __init__(self,key):
        self.key=key
        self.left=None
        self.right=None
root=Node("A")
root.left=Node("B")
root.right=Node("C")
root.left.left=Node("D")
root.right.right=Node("E")
root.left.left.right=Node("F")
root.right.right.left=Node("G")

def inorder(node, result):
    if node is None:
        return 
    inorder(node.left, result)
    result.append(node.key)
    inorder(node.right, result)
result=[]
inorder(root, result)
print(result)
# Out:
# ['D', 'F', 'B', 'A', 'C', 'G', 'E']

# %%
class Node:
    def __init__(self,key):
        self.key=key
        self.left=None
        self.right=None

root=Node(10)
root.left=Node(25)
root.right=Node(80)
root.left.right=Node(30)
root.right.left=Node(70)
root.left.right.left=Node(28)
root.right.left.right=Node(75)

def inorder(node,result):
    if node is None:
        return
    inorder(node.left,result)
    result.append(node.key)
    inorder(node.right, result)
result=[]
inorder(root,result)
print(result)
# Out:
# [25, 28, 30, 10, 70, 75, 80]

# %%
class Node:
    def __init__(self,key):
        self.key=key
        self.left=None
        self.right=None

root=Node(1)
root.right=Node(2)
root.right.left=Node(3)
root.right.left.right=Node(4)
def inorder(node, result):
    if node is None:
        return
    inorder(node.left,result)
    result.append(node.key)
    inorder(node.right,result)
result=[]
inorder(root,result)
print(result)
# Out:
# [1, 3, 4, 2]

# %%
class Node:
    def __init__(self,key):
        self.key=key
        self.left=None
        self.right=None
root=Node(9)
root.left=Node(4)
root.right=Node(7)
root.left.left=Node(2)
root.left.right=Node(6)
root.right.left=Node(5)
root.right.right=Node(8)
root.left.right.left=Node(3)
root.right.right.right=Node(1)
def inorder(node,result):
    if node is None:
        return
    inorder(node.left, result)
    result.append(node.key)
    inorder(node.right,result)
result=[]
inorder(root,result)
print(result)
# Out:
# [2, 4, 3, 6, 9, 5, 7, 8, 1]

# %% [markdown]
# postorder

# %%
class Node:
    def __init__(self, key):
        self.key=key
        self.left=None
        self.right=None
root=Node(20)
root.left=Node(10)
root.right=Node(30)
root.left.left=Node(5)
root.right.left=Node(25)
root.right.right=Node(40)
root.left.left.right=Node(7)
def postorder(node, result):
    if node is None:
        return
    postorder(node.left, result)
    postorder(node.right, result)
    result.append(node.key)

result=[]
postorder(root,result)
print(result)
# Out:
# [7, 5, 10, 25, 40, 30, 20]

# %% [markdown]
# Preorder aur inorder dene k baad, poora tree reconstruct karna kaise hai wo samajhte hai

# %%
class Node:
    def __init__(self,key):
        self.key=key
        self.left=Node
        self.right=Node
def build_tree(preorder, inorder):
    if len(preorder)==0:
        return None
    root_value=preorder[0]
    root=Node(root_value)
    root_index=inorder.index(root_value)
    left_inorder=inorder[:root_value]
    right_inorder=inorder[root_value+1:]
    left_size=len(left_inorder)
    left_preorder=preorder[1:1+left_size]
    right_preorder=preorder[1+left_size:]
    
class Node:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None


# def build_tree(preorder, inorder):
#     if len(preorder) == 0:
#         return None

#     root_value = preorder[0]
#     root = Node(root_value)

#     root_index = inorder.index(root_value)

#     left_inorder = inorder[:root_index]
#     right_inorder = inorder[root_index + 1:]

#     left_size = len(left_inorder)

#     left_preorder = preorder[1:1 + left_size]
#     right_preorder = preorder[1 + left_size:]

#     root.left = build_tree(left_preorder, left_inorder)
#     root.right = build_tree(right_preorder, right_inorder)

#     return root


# def postorder(node, result):
#     if node is None:
#         return

#     postorder(node.left, result)
#     postorder(node.right, result)
#     result.append(node.key)


# preorder_values = ["A", "B", "D", "E", "C", "F"]
# inorder_values = ["D", "B", "E", "A", "C", "F"]

# root = build_tree(preorder_values, inorder_values)

# result = []
# postorder(root, result)

# print(result)
# print(" ".join(result))
