# %% [markdown]
# Trying out Exercise 5
# size badhte rehna chahiye... import ctype
# array... [capacity,data]

# %%
import ctypes

# %%
import ctypes

# %%
from array import array
jersey=array('i',[18,])
